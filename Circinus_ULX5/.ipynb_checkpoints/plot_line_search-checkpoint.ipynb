# %%
# %matplotlib widget
# %matplotlib inline
import sys
from sys import platform
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import numpy as np
import seaborn as sns
import scipy.signal as signal
from IPython.display import display, Math
from tqdm import tqdm

from astropy.io import fits, ascii
from astropy.table import Table
from astropy.modeling import functional_models, fitting
from astropy.timeseries import LombScargle

sns.set_context('talk')
# sns.set_style("whitegrid")
sns.set_palette("colorblind")

root_dir = '/Volumes/Samsung_1TB/AstroData/Circinus_ULX5/'

# %% [markdown]
# # NuSTAR

# %%
infile = root_dir + 'nustar/simultaneous_highstate/tbabs_simpl_diskbb_gauss_cstat.csv'
data = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
plt.figure(figsize=(15,9))
plt.plot(data['Energy'], data['cstat_new']-data['cstat0'])
plt.axhline(0.0)
plt.xscale('log')
plt.ylabel(r'$\Delta\ C$')
plt.xlabel('Energy (keV)')

# peaks, _ = signal.find_peaks(data['cstat0'] - data['cstat_new'], threshold=0.13)
# print(data['Energy'][peaks])
# plt.plot(data['Energy'][peaks], (data['cstat_new']-data['cstat0'])[peaks], "x", markersize=20)
# Out:
# Text(0.5, 0, 'Energy (keV)')

# %%
infile = root_dir + 'nustar/simultaneous_highstate/tbfeo_simpl_diskbb_gauss_cstat.csv'
data_sim = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'nustar/nustar_30002038002/30002038002_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
data_002 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'nustar/nustar_30002038004/30002038004_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
data_004 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'nustar/nustar_30002038006/30002038006_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
data_006 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'nustar/nustar_80601502001/80601502001_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
data_806 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5,1, sharex=True,  gridspec_kw = {'height_ratios':[1, 1,1,1,1], 'hspace':0}, figsize=(15, 20))

ax1.plot(data_002['Energy'], data_002['cstat_new']-data_002['cstat0'])
ax1.axhline(0.0, color='red', lw=0.5)

ax2.plot(data_004['Energy'], data_004['cstat_new']-data_004['cstat0'])
ax2.axhline(0.0, color='red', lw=0.5)

ax3.plot(data_006['Energy'], data_006['cstat_new']-data_006['cstat0'])
ax3.axhline(0.0, color='red', lw=0.5)

ax4.plot(data_806['Energy'], data_806['cstat_new']-data_806['cstat0'])
ax4.axhline(0.0, color='red', lw=0.5)

ax5.plot(data_sim['Energy'], data_sim['cstat_new']-data_sim['cstat0'])
ax5.axhline(0.0, color='red', lw=0.5)

plt.xscale('log')
ax3.set_ylabel(r'$\Delta\ C$', fontsize=32)
ax5.set_xlabel('Energy (keV)', fontsize=32)

plt.tight_layout()
plt.savefig(root_dir + 'figures/NuSTAR_abs_scan.pdf')

# peaks, _ = signal.find_peaks(data['cstat0'] - data['cstat_new'], threshold=0.13)
# print(data['Energy'][peaks])
# plt.plot(data['Energy'][peaks], (data['cstat_new']-data['cstat0'])[peaks], "x", markersize=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1bd9c09e6fdb> in <module>
# ----> 1 infile = root_dir + 'nustar/simultaneous_highstate/tbfeo_simpl_diskbb_gauss_cstat.csv'
#       2 data_sim = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
#       3 infile = root_dir + 'nustar/nustar_30002038002/30002038002_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
#       4 data_002 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
#       5 infile = root_dir + 'nustar/nustar_30002038004/30002038004_products/tbfeo_simpl_diskbb_gabs_cstat.csv'
#
# NameError: name 'root_dir' is not defined

# %% [markdown]
# # XMM

# %%
infile = root_dir + 'xmm/0111240101/products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat.csv'
data_011 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'xmm/0701981001/products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat.csv'
data_070 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'xmm/0780950201/products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat.csv'
data_078 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'xmm/0792382701/products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat.csv'
data_079 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'xmm/0824450301/0824450301_products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat.csv'
data_082 = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'xmm/simultaneous_fitting/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat_all.csv'
data_sim_all = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
# infile = root_dir + 'xmm/simultaneous_fitting/tbfeo_diskbb_simpl_diskbb_gabs_cstat.csv'
# data_sim = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])

# fluxes = {'0111240101': 1.2e-12, '0701981001': 4.6e-12,'0780950201': 8.4e-13,'0792382701': 8.9e-13,'0824450301': 4.2e-12}

# fig, (ax1, ax2) = plt.subplots(2,1, sharex=True,  gridspec_kw = {'height_ratios':[1,1], 'hspace':0}, figsize=(15, 8))

# ax1.plot(data_011['Energy'], data_011['cstat_new']-data_011['cstat0'])
# ax1.axhline(0.0, color='red', lw=0.5)
# ax1.axvline(0.87, color='red')
# ax1.text(0.3,-5, '0111240101', fontsize=20)

# ax2.plot(data_070['Energy'], data_070['cstat_new']-data_070['cstat0'])
# ax2.axhline(0.0, color='red', lw=0.5)
# ax2.axvline(0.87, color='red')
# ax2.text(0.3,-7.5, '0701981001', fontsize=20)

# plt.xscale('log')
# ax1.set_ylabel(r'$\Delta\ C$', fontsize=32)
# ax2.set_xlabel('Energy (keV)', fontsize=32)

# plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_scan_011_070.pdf')

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, sharex=True,  gridspec_kw = {'height_ratios':[1,1,1,1], 'hspace':0}, figsize=(15, 16))

# ax1.plot(data_078['Energy'], data_078['cstat_new']-data_078['cstat0'])
# ax1.axhline(0.0, color='red', lw=0.5)
# ax1.axvline(0.87, color='red')
# ax1.text(0.3,-4, '0780950201', fontsize=20)

# ax2.plot(data_079['Energy'], data_079['cstat_new']-data_079['cstat0'])
# ax2.axhline(0.0, color='red', lw=0.5)
# ax2.axvline(0.87, color='red')
# ax2.text(0.3,-5, '0792382701', fontsize=20)

# ax3.plot(data_082['Energy'], data_082['cstat_new']-data_082['cstat0'])
# ax3.axhline(0.0, color='red', lw=0.5)
# ax3.axvline(0.87, color='red')
# ax3.text(0.3,-9, '0824450301', fontsize=20)

# ax4.plot(data_sim['Energy'], data_sim['cstat_new']-data_sim['cstat0'])
# ax4.axhline(0.0, color='red', lw=0.5)
# ax4.axvline(0.87, color='red')
# ax4.text(0.3,-14, 'Simultaneous fitting', fontsize=20)

# plt.xscale('log')
# ax2.set_ylabel(r'$\Delta\ C$', fontsize=32)
# ax4.set_xlabel('Energy (keV)', fontsize=32)

# plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_scan.pdf')

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6,1, sharex=True,  gridspec_kw = {'height_ratios':[1,1,1,1,1,1], 'hspace':0}, figsize=(15, 24))

ax1.plot(12.4/data_011['Energy'], data_011['cstat_new']-data_011['cstat0'])
ax1.axhline(0.0, color='red', lw=0.5)
# ax1.axvline(0.87, color='red')
ax1.text(20,-3, '0111240101', fontsize=20)

ax2.plot(12.4/data_070['Energy'], data_070['cstat_new']-data_070['cstat0'])
ax2.axhline(0.0, color='red', lw=0.5)
# ax2.axvline(0.87, color='red')
ax2.text(20,-3, '0701981001', fontsize=20)

ax3.plot(12.4/data_078['Energy'], data_078['cstat_new']-data_078['cstat0'])
ax3.axhline(0.0, color='red', lw=0.5)
# ax3.axvline(0.87, color='red')
ax3.text(20,-3, '0780950201', fontsize=20)

ax4.plot(12.4/data_079['Energy'], data_079['cstat_new']-data_079['cstat0'])
ax4.axhline(0.0, color='red', lw=0.5)
# ax4.axvline(0.87, color='red')
ax4.text(20,-3, '0792382701', fontsize=20)

ax5.plot(12.4/data_082['Energy'], data_082['cstat_new']-data_082['cstat0'])
ax5.axhline(0.0, color='red', lw=0.5)
# ax5.axvline(0.87, color='red')
ax5.text(20,-3, '0824450301', fontsize=20)

ax6.plot(12.4/data_sim_all['Energy'], data_sim_all['cstat_new']-data_sim_all['cstat0'])
ax6.axhline(0.0, color='red', lw=0.5)
# ax6.axvline(0.87, color='red')
ax6.text(20,-3, 'Simultaneous fitting', fontsize=20)

# ax6.plot(data_sim_all['Energy'], (data_011['cstat_new']-data_011['cstat0']) + (data_070['cstat_new']-data_070['cstat0']) + \
#                                              (data_078['cstat_new']-data_078['cstat0']) + (data_079['cstat_new']-data_079['cstat0'])+ \
#                                              (data_082['cstat_new']-data_082['cstat0']))
ax6.axhline(0.0, color='red', lw=0.5)
# ax6.axvline(0.87, color='red')

plt.xscale('log')
ax3.set_ylabel(r'$\Delta\ C$', fontsize=32)
ax6.set_xlabel(r'$\mathrm{Wavelength}\ (\AA)$', fontsize=32)
ax1.set_xlim(right=30.)

plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_scan_all.pdf')



# peaks, _ = signal.find_peaks(data['cstat0'] - data['cstat_new'], threshold=0.13)
# print(data['Energy'][peaks])
# plt.plot(data['Energy'][peaks], (data['cstat_new']-data['cstat0'])[peaks], "x", markersize=20)

# %%
infile = root_dir + 'xmm/simultaneous_fitting/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_cstat_all.csv'
data_xmm_all = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])
infile = root_dir + 'nustar/simultaneous_highstate/tbfeo_simpl_diskbb_gabs_1000kms_cstat.csv'
data_nustar_all = ascii.read(infile, format='csv', data_start=0, names=['Energy', 'cstat0', 'cstat_new'])


fig, (ax1, ax2) = plt.subplots(2,1, sharex=True,  gridspec_kw = {'height_ratios':[1,1], 'hspace':0}, figsize=(15, 8))

# ax1.plot(12.4/data_xmm_all['Energy'], data_xmm_all['cstat_new']-data_xmm_all['cstat0'])
ax1.plot(data_xmm_all['Energy'], data_xmm_all['cstat_new']-data_xmm_all['cstat0'])
ax1.axhline(0.0, color='red', lw=0.5)
# ax1.axvline(0.87, color='red')
# ax1.text(20,-3, 'XMM', fontsize=20)

# ax2.plot(12.4/data_nustar_all['Energy'], data_nustar_all['cstat_new']-data_nustar_all['cstat0'])
ax2.plot(data_nustar_all['Energy'], data_nustar_all['cstat_new']-data_nustar_all['cstat0'])
ax2.axhline(0.0, color='red', lw=0.5)
# ax2.text(20,-3, 'NuSTAR', fontsize=20)


plt.xscale('log')
ax1.set_ylabel(r'$\Delta\ C$', fontsize=32)
# ax2.set_xlabel(r'$\mathrm{Wavelength}\ (\AA)$', fontsize=32)
ax2.set_xlabel('Energy (eV)', fontsize=32)
# ax1.set_xlim(right=30.)

plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_scan_all.pdf')



# peaks, _ = signal.find_peaks(data['cstat0'] - data['cstat_new'], threshold=0.13)
# print(data['Energy'][peaks])
# plt.plot(data['Energy'][peaks], (data['cstat_new']-data['cstat0'])[peaks], "x", markersize=20)

# %%
infile_root = root_dir + 'xmm/0824450301/0824450301_products/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_detlev_cstat_'
min_deltac = []
for i in range(5):
    infile= infile_root + str(i+1) + '.csv'
    data = ascii.read(infile, format='csv', data_start=0, names=['n_sim', 'energy', 'cstat0', 'cstat_new'])
    for j in range(500):
        if len(data[data['n_sim']==(j+1)]) == 1941:
            deltac = (data[data['n_sim']==(j+1)]['cstat_new']) - (data[data['n_sim']==(j+1)]['cstat0'])
            min_deltac.append(np.min(deltac))

plt.hist(min_deltac)

print(len(min_deltac))

two_sigma_cutoff = int(0.9545*len(min_deltac))
two_sigma_cstat = np.sort(min_deltac)[-two_sigma_cutoff]
twohalf_sigma_cutoff = int(0.9876*len(min_deltac))
twohalf_sigma_cstat = np.sort(min_deltac)[-twohalf_sigma_cutoff]

print(two_sigma_cstat)
print(twohalf_sigma_cstat)
            
# better_mask = delta_chi <= delta_chi0

# print(np.sum(better_mask))
# print(len(delta_chi))
# print(np.sum(better_mask)/len(delta_chi))

# plt.figure(figsize=(16,9))
# plt.hist(-delta_chi, bins=50)
# plt.axvline(-delta_chi0, color='red')
# plt.xlabel(r'$\Delta C$', fontsize=28)
# plt.ylabel('Number of simulations', fontsize=28)
# plt.yscale('log')

# plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_detlev.pdf')
# Out:
# 310
# -9.949999999999989
# -12.050000000000011

# %%
infile_root = root_dir + 'xmm/simultaneous_fitting/tbfeo_diskbb_simpl_diskbb_gabs_1000kms_detlev_cstat_'
min_deltac = []
for i in range(5):
    infile= infile_root + str(i+1) + '.csv'
    data = ascii.read(infile, format='csv', data_start=0, names=['n_sim', 'energy', 'cstat0', 'cstat_new'])
    for j in range(500):
        if len(data[data['n_sim']==(j+1)]) == 1941:
            deltac = (data[data['n_sim']==(j+1)]['cstat_new']) - (data[data['n_sim']==(j+1)]['cstat0'])
            min_deltac.append(np.min(deltac))

plt.hist(min_deltac)

print(len(min_deltac))

two_sigma_cutoff = int(0.9545*len(min_deltac))
two_sigma_cstat = np.sort(min_deltac)[-two_sigma_cutoff]
twohalf_sigma_cutoff = int(0.9876*len(min_deltac))
twohalf_sigma_cstat = np.sort(min_deltac)[-twohalf_sigma_cutoff]

print(two_sigma_cstat)
print(twohalf_sigma_cstat)
            
# better_mask = delta_chi <= delta_chi0

# print(np.sum(better_mask))
# print(len(delta_chi))
# print(np.sum(better_mask)/len(delta_chi))

# plt.figure(figsize=(16,9))
# plt.hist(-delta_chi, bins=50)
# plt.axvline(-delta_chi0, color='red')
# plt.xlabel(r'$\Delta C$', fontsize=28)
# plt.ylabel('Number of simulations', fontsize=28)
# plt.yscale('log')

# plt.tight_layout()
# plt.savefig(root_dir + 'figures/XMM_abs_detlev.pdf')
# Out:
# 70
# -10.289999999999964
# -12.919999999999845

# %%
infile = root_dir + 'xmm/simultaneous_fitting/tbfeo_diskbb_simpl_diskbb_gabs_detlev_cstat.csv'
data = ascii.read(infile, format='csv', data_start=0, names=['n_sim', 'cstat0', 'cstat_new'])
# delta_chi0 = 984.46-967.28
delta_chi0 = 974.59-958.28
delta_chi = data['cstat0'] - data['cstat_new']

better_mask = delta_chi <= delta_chi0

print(np.sum(better_mask))
print(len(delta_chi))
print(np.sum(better_mask)/len(delta_chi))

plt.figure(figsize=(16,9))
plt.hist(-delta_chi, bins=50)
plt.axvline(-delta_chi0, color='red')
plt.xlabel(r'$\Delta C$', fontsize=28)
plt.ylabel('Number of simulations', fontsize=28)
plt.yscale('log')

plt.tight_layout()
plt.savefig(root_dir + 'figures/XMM_abs_detlev.pdf')
# Out:
# 999
# 1000
# 0.999
